# %%
from lib.notebook_imports import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %load_ext autoreload
# %autoreload 2

shap.initjs()

start_time = datetime.now()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# # READ DATA

# %%
data_900 = read_data('/dysk1/approx/invicta/1.1.1./', merge_with_meds=True, merge_with_patient_genes=True)
data_900_df = data_900.input_df
data_2015_df = read_data_2015('/dysk1/approx/invicta/1.1.1./')

LGB_PARAMS_BASE, N_FOLDS, ALL_MODEL_SUFFIXES, BASE_COLS_1, BASE_COLS_2 = get_consts()

DATA_SERIES_900, DATA_SERIES_2015, DATA_SERIES = prepare_data_series(data_900_df, data_2015_df, N_FOLDS)
# Out:
# Converting ds_789_result_num_E2 to float
# Converting amh_qual_result_num to float
# Converting qual_result_num_FSH to float
# Converting qual_result_num_DHEAS to float
# Converting qual_result_num_Inh_B to float
# Converting qual_result_num_TST to float
# Converting qual_result_num_anty_TPO to float
# Converting qual_result_num_TSH to float
# Converting qual_result_num_SHBG to float
# weight    0.503356
# height    0.492170
# bmi       0.460850
# dtype: float64
# pickups_df:                  981
# merged with meds_df:         936
# merged with patient_gens_df: 922
# merged with poli_changes_df: 922
# merged with causes_df: 922
# merged with patient_groups_df: 922
# merged with body_df: 922
# -
# dhea_s:          low: 2%,  normal: 87%, high: 11%, filled: 63%, ()
# shbg:            low: 1%,  normal: 80%, high: 19%, filled: 39%, ()
# testosterone:    low: 49%, normal: 46%, high: 5%, filled: 40%, ()
# fsh:             low: 9%,  normal: 64%, high: 26%, filled: 45%, (?)
# ...

# %% [markdown]
# # BASE EXPERIMENTS

# %%
BASE_RESULTS = perform_base_experiments(
    LGB_PARAMS_BASE,
    DATA_SERIES,
    ALL_MODEL_SUFFIXES,
    ['l2'],
    [BASE_COLS_1, BASE_COLS_2]
)
# Out:
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# -
# ...

# %%
PROT_SETS = prepare_protocol_sets(data_2015_df)

# %% [markdown]
# # KRR

# %%
merged_test_df_900 = BASE_RESULTS[1].get_merged_test_dfs_from_folds('900_day_0_mii')
merged_test_df_2015 = BASE_RESULTS[1].get_merged_test_dfs_from_folds('2015_day_0_mii')

# %%
THERAPY_PREDICTOR_CLASS_NAMES = [
    'KernelRidgePredictor',
    'KernelRidgeLogPredictor',
    'GausianProcessRegressorPredictor',
    'GausianProcessRegressorLogPredictor',
    'LGBMPredictor',
    'LGBMLogPredictor',
]
THERAPY_PREDICTOR_FACTORY_MII = TherapyPredictorFactory(
    'prediction_l2',
    'day_0_mii',
    LGB_PARAMS_BASE,
)

# %% [markdown]
# # DATA_900

# %%
MERGED_TEST_DF = merged_test_df_900
PLOT_DOTS = True
X_COL = 'prediction_l2'
Y_COL = 'day_0_mii'

# %%
plot_all_models(
    X_COL,
    Y_COL,
    THERAPY_PREDICTOR_FACTORY_MII,
    THERAPY_PREDICTOR_CLASS_NAMES,
    MERGED_TEST_DF,
    DataFilter(None)
)
# Out:
# Fitting KernelRidgePredictor: 516: 0:00:02.507830
# Fitting KernelRidgePredictor: 516: 0:00:02.513563
# Fitting GausianProcessRegressorPredictor: 516: 0:00:11.240727
# Fitting GausianProcessRegressorPredictor: 516: 0:00:08.283242
# Fitting LGBMPredictor: 516: 0:00:00.122359
# Fitting LGBMPredictor: 516: 0:00:00.025469

# %%
plot_protocols(
    X_COL,
    Y_COL,
    THERAPY_PREDICTOR_FACTORY_MII,
    'KernelRidgePredictor',
    MERGED_TEST_DF,
    PROT_SETS.DS1_3_DAWKA_DZIENNA,
    PLOT_DOTS,
)
# Out:
# Fitting KernelRidgePredictor: 237: 0:00:01.076568
# Fitting KernelRidgePredictor: 94: 0:00:00.779825
# Fitting KernelRidgePredictor: 48: 0:00:00.418243

# %% [markdown]
# # DATA_2015 - MII

# %%
MERGED_TEST_DF = merged_test_df_2015
PLOT_DOTS = True
X_COL = 'prediction_l2'
Y_COL = 'day_0_mii'

# %%
# %%time

plot_protocols(
    X_COL,
    Y_COL,
    THERAPY_PREDICTOR_FACTORY_MII,
    'KernelRidgePredictor',
    MERGED_TEST_DF,
    PROT_SETS.DS1_3_DAWKA_DZIENNA,
    PLOT_DOTS,
)
# Out:
# Fitting KernelRidgePredictor: 3046: 0:00:43.892537
# Fitting KernelRidgePredictor: 2298: 0:00:28.107101
# Fitting KernelRidgePredictor: 906: 0:00:06.878767
# CPU times: user 17min 12s, sys: 20min 58s, total: 38min 10s
# Wall time: 1min 19s

# %%
from sklearn.neighbors import KernelDensity

# %%
def plot_kde_density_for_protocols(
        x_col: str,
        df: pd.DataFrame,
        protocol_list: List[DataFilter]
    ):
    
    _fig, _ax = plt.subplots(1, 1, figsize=(12, 10))

    X_plot = np.linspace(0, max(df[x_col]), 1000)[:, None]
    for protocol_number, protocol_data_filter in enumerate(protocol_list):

        filter_name = protocol_data_filter.get_name()
        filtered_df, filtered_percentage = protocol_data_filter.filter_data(df)
        color = get_color(protocol_number)

        kde = KernelDensity(kernel='gaussian', bandwidth=0.20).fit(filtered_df[[x_col]])
        kde_plot = kde.score_samples(X_plot)
        plt.plot(X_plot, np.exp(kde_plot), '-', color=color, label=f'{filter_name}: {filtered_percentage}%')

        
    plt.xlabel(x_col)
    plt.ylabel('kernel density (gaussian)')
    plt.title(f'kernel density')

    plt.legend()
    plt.show()

# %%
# %%time

plot_kde_density_for_protocols(
    X_COL,
    MERGED_TEST_DF,
    PROT_SETS.DS1_3_DAWKA_DZIENNA,
)
# Out:
# CPU times: user 558 ms, sys: 5.67 ms, total: 564 ms
# Wall time: 561 ms

# %%
# %%time

plot_kde_density_for_protocols(
    X_COL,
    MERGED_TEST_DF,
    PROT_SETS.PROT_TYPE,
)
# Out:
# CPU times: user 728 ms, sys: 15.2 ms, total: 743 ms
# Wall time: 740 ms

# %%
# %%time

plot_kde_density_for_protocols(
    X_COL,
    MERGED_TEST_DF,
    PROT_SETS.DS4_7_DAWKA_DZIENNA,
)
# Out:
# CPU times: user 609 ms, sys: 16.5 ms, total: 625 ms
# Wall time: 622 ms

# %%
# %%time

plot_kde_density_for_protocols(
    X_COL,
    MERGED_TEST_DF,
    PROT_SETS.DOSING_PROTOCOLS_SHORTLIST,
)
# Out:
# CPU times: user 1.02 s, sys: 35.2 ms, total: 1.06 s
# Wall time: 1.05 s

# %%
# %%time

plot_kde_density_for_protocols(
    'prediction_h20',
    MERGED_TEST_DF,
    PROT_SETS.DS1_3_DAWKA_DZIENNA,
)
# Out:
# CPU times: user 765 ms, sys: 28.9 ms, total: 794 ms
# Wall time: 793 ms

# %%
# %%time

plot_kde_density_for_protocols(
    'prediction_h25',
    MERGED_TEST_DF,
    PROT_SETS.DS1_3_DAWKA_DZIENNA,
)
# Out:
# CPU times: user 1.14 s, sys: 17.8 ms, total: 1.16 s
# Wall time: 1.17 s

# %%
len(MERGED_TEST_DF[MERGED_TEST_DF['hiper_20']])
# Out:
# 879
