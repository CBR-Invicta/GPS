# %%
from lib.notebook_imports import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %load_ext autoreload
# %autoreload 2

shap.initjs()

start_time = datetime.now()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# # READ DATA

# %%
data_900 = read_data('/dysk1/approx/invicta/1.1.1./', merge_with_meds=True, merge_with_patient_genes=True)
data_900_df = data_900.input_df
data_2015_df = read_data_2015('/dysk1/approx/invicta/1.1.1./')

LGB_PARAMS_BASE, N_FOLDS, ALL_MODEL_SUFFIXES, BASE_COLS_1, BASE_COLS_2 = get_consts()

DATA_SERIES_900, DATA_SERIES_2015, DATA_SERIES = prepare_data_series(data_900_df, data_2015_df, N_FOLDS)
# Out:
# Converting ds_789_result_num_E2 to float
# Converting amh_qual_result_num to float
# Converting qual_result_num_FSH to float
# Converting qual_result_num_DHEAS to float
# Converting qual_result_num_Inh_B to float
# Converting qual_result_num_TST to float
# Converting qual_result_num_anty_TPO to float
# Converting qual_result_num_TSH to float
# Converting qual_result_num_SHBG to float
# weight    0.503356
# height    0.492170
# bmi       0.460850
# dtype: float64
# pickups_df:                  981
# merged with meds_df:         936
# merged with patient_gens_df: 922
# merged with poli_changes_df: 922
# merged with causes_df: 922
# merged with patient_groups_df: 922
# merged with body_df: 922
# -
# dhea_s:          low: 2%,  normal: 87%, high: 11%, filled: 63%, ()
# shbg:            low: 1%,  normal: 80%, high: 19%, filled: 39%, ()
# testosterone:    low: 49%, normal: 46%, high: 5%, filled: 40%, ()
# fsh:             low: 9%,  normal: 64%, high: 26%, filled: 45%, (?)
# ...

# %% [markdown]
# # BASE EXPERIMENTS

# %%
BASE_RESULTS = perform_base_experiments(
    LGB_PARAMS_BASE,
    DATA_SERIES,
    ALL_MODEL_SUFFIXES,
    #['l2', 'h20'],
    ['h20', 'h25'],
    [BASE_COLS_1, BASE_COLS_2]
)
# Out:
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# -
# ...

# %% [markdown]
# # ROC CURVE

# %%
show_roc_curve(BASE_RESULTS[1], '2015_hiper_20', '2015_day_0_mii', 'hiper_20', 'prediction_h20')

# %%
show_roc_curve(BASE_RESULTS[1], '2015_hiper_25', '2015_day_0_mii', 'hiper_25', 'prediction_h25')

# %%
show_roc_curve(BASE_RESULTS[1], '900_hiper_20', '900_day_0_mii', 'hiper_20', 'prediction_h20')

# %%
show_roc_curve(BASE_RESULTS[1], '900_hiper_25', '900_day_0_mii', 'hiper_25', 'prediction_h25')

# %% [markdown]
# # ADD CAUSE_PCO TO MODEL

# %%
data_2015_df['cause_pco'].value_counts(dropna=False, normalize=True)
# Out:
# 0.0    0.954983
# 1.0    0.045017
# Name: cause_pco, dtype: float64

# %%
MERGED_BASE2_TEST_DF = BASE_RESULTS[1].get_merged_test_dfs_from_folds('2015_day_0_mii')

# %%
pco = len(MERGED_BASE2_TEST_DF[
    (MERGED_BASE2_TEST_DF['cause_pco'] == 1)
])

# %%
pco_h20 = len(MERGED_BASE2_TEST_DF[
    (MERGED_BASE2_TEST_DF['cause_pco'] == 1)
    &
    (MERGED_BASE2_TEST_DF['hiper_20'])
])

# %%
pco_h25 = len(MERGED_BASE2_TEST_DF[
    (MERGED_BASE2_TEST_DF['cause_pco'] == 1)
    &
    (MERGED_BASE2_TEST_DF['hiper_25'])
])

# %%
total = len(MERGED_BASE2_TEST_DF)

# %%
h20 = len(MERGED_BASE2_TEST_DF[
    (MERGED_BASE2_TEST_DF['hiper_20'])
])

# %%
h25 = len(MERGED_BASE2_TEST_DF[
    (MERGED_BASE2_TEST_DF['hiper_25'])
])

# %%
pco_h20 / pco
# Out:
# 0.30900243309002434

# %%
h20 / total
# Out:
# 0.10103448275862069

# %%
pco_h25 / pco
# Out:
# 0.15085158150851583

# %%
h25 / total
# Out:
# 0.03816091954022988

# %%
print_cols(BASE_COLS_2)
# Out:
# Number of columns: 5
# -
#     "test_amh_r",
#     "patient_age",
#     "ds1_pech_licz_10_pon",
#     "prev_proc-cumulus_denuded",
#     "prev_proc-day_0_mii",
# -

# %%
cols = [
    "test_amh_r",
    "patient_age",
    "ds1_pech_licz_10_pon",
    "prev_proc-cumulus_denuded",
    "prev_proc-day_0_mii",
]

# %%
Y_RESULTS = train_data_series(
    LGB_PARAMS_BASE,
    DATA_SERIES,
    cols,
    model_suffixes_filter=ALL_MODEL_SUFFIXES)

Y_RESULTS.print_errors(
    BASE_RESULTS,
    print_suffixes=['h20', 'h25'],
    print_avg=True,
)
# Out:
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# divide by zero encountered in double_scalars
# -
# RMSE[fold_avg][h20][900_cumulus_denuded]:      count:530    avg:7.64   0.25    (0.00)    (0.00)
# ...

# %%
fold_info = Y_RESULTS.train_infos['2015_day_0_mii'].fold_infos[0]

# %%
explainer = shap.TreeExplainer(fold_info.lgb_models['h25'])
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
train_shap_values = explainer.shap_values(fold_info.train_df[fold_info.train_cols])
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %%
shap.summary_plot(
    train_shap_values,
    fold_info.train_df[fold_info.train_cols]
)

# %%
show_roc_curve(BASE_RESULTS[1], '2015_hiper_20', '2015_day_0_mii', 'hiper_20', 'prediction_h20')

# %%
show_roc_curve(Y_RESULTS, '2015_hiper_20', '2015_day_0_mii', 'hiper_20', 'prediction_h20')

# %%
show_roc_curve(BASE_RESULTS[1], '2015_hiper_25', '2015_day_0_mii', 'hiper_25', 'prediction_h25')

# %%
show_roc_curve(Y_RESULTS, '2015_hiper_25', '2015_day_0_mii', 'hiper_25', 'prediction_h25')

# %%
show_roc_curve(BASE_RESULTS[1], '900_hiper_20', '900_day_0_mii', 'hiper_20', 'prediction_h20')

# %%
show_roc_curve(Y_RESULTS, '900_hiper_20', '900_day_0_mii', 'hiper_20', 'prediction_h20')

# %%
show_roc_curve(BASE_RESULTS[1], '900_hiper_25', '900_day_0_mii', 'hiper_25', 'prediction_h25')

# %%
show_roc_curve(Y_RESULTS, '900_hiper_25', '900_day_0_mii', 'hiper_25', 'prediction_h25')

# %%
print(f'DONE: {format(datetime.now() - start_time)}')
# Out:
# DONE: 0:08:44.903535
